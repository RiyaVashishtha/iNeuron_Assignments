# %% [markdown]
# # iNEURON PANDAS ASSIGNMENT

# %% [markdown]
# # Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
import pandas as pd
df = pd.read_csv('sales_order_data.csv')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  \
# 0        10107               30      95.70                2  2871.00  Shipped
# 1        10121               34      81.35                5  2765.90  Shipped
# 2        10134               41      94.74                2  3884.34  Shipped
# 3        10145               45      83.26                6  3746.70  Shipped
# 4        10159               49     100.00               14  5205.27  Shipped
#
#    QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  PRODUCTCODE             PHONE  \
# 0       1         2     2003  Motorcycles  ...     S10_1678        2125557818
# 1       2         5     2003  Motorcycles  ...     S10_1678        26.47.1555
# 2       3         7     2003  Motorcycles  ...     S10_1678  +33 1 46 62 7555
# 3       3         8     2003  Motorcycles  ...     S10_1678        6265557265
# 4       4        10     2003  Motorcycles  ...     S10_1678        6505551386
#
# ...

# %% [markdown]
# # Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
print(df['STATUS'].dtype)

print(df['PRICEEACH'].dtype)
# Out:
# object
# float64

# %% [markdown]
# # Q3. How do you select rows from a Pandas DataFrame based on a condition?

# %%
# This will create a new DataFrame object 'new_df' that contains only the rows where the value in 'column_name' is greater than 10.

new_df = df[df['QUANTITYORDERED'] > 10]
print(new_df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#         STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  PRODUCTCODE  \
# ...

# %% [markdown]
# # Q4. How do you rename columns in a Pandas DataFrame?

# %%
df = df.rename(columns={'ORDERNUMBER': 'ORDERNO'})
print(df)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  \
# 0       10107               30      95.70                2  2871.00   Shipped
# 1       10121               34      81.35                5  2765.90   Shipped
# 2       10134               41      94.74                2  3884.34   Shipped
# 3       10145               45      83.26                6  3746.70   Shipped
# 4       10159               49     100.00               14  5205.27   Shipped
# ...       ...              ...        ...              ...      ...       ...
# 2818    10350               20     100.00               15  2244.40   Shipped
# 2819    10373               29     100.00                1  3978.51   Shipped
# 2820    10386               43     100.00                4  5417.57  Resolved
# 2821    10397               34      62.24                1  2116.16   Shipped
# 2822    10414               47      65.52                9  3079.44   On Hold
#
# ...

# %% [markdown]
# # Q5. How do you drop columns in a Pandas DataFrame?

# %%
df = df.drop(['DEALSIZE'], axis=1)
print(df)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  \
# 0       10107               30      95.70                2  2871.00   Shipped
# 1       10121               34      81.35                5  2765.90   Shipped
# 2       10134               41      94.74                2  3884.34   Shipped
# 3       10145               45      83.26                6  3746.70   Shipped
# 4       10159               49     100.00               14  5205.27   Shipped
# ...       ...              ...        ...              ...      ...       ...
# 2818    10350               20     100.00               15  2244.40   Shipped
# 2819    10373               29     100.00                1  3978.51   Shipped
# 2820    10386               43     100.00                4  5417.57  Resolved
# 2821    10397               34      62.24                1  2116.16   Shipped
# 2822    10414               47      65.52                9  3079.44   On Hold
#
# ...

# %% [markdown]
# # Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
unique_values = df['PRODUCTLINE'].unique()
print(unique_values)
# Out:
# ['Motorcycles' 'Classic Cars' 'Trucks and Buses' 'Vintage Cars' 'Planes'
#  'Ships' 'Trains']

# %% [markdown]
# # Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
df.isna().sum()
# Out:
# ORDERNO                0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# PHONE                  0
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# dtype: int64

# %%
df.isna().any()
# Out:
# ORDERNO             False
# QUANTITYORDERED     False
# PRICEEACH           False
# ORDERLINENUMBER     False
# SALES               False
# STATUS              False
# QTR_ID              False
# MONTH_ID            False
# YEAR_ID             False
# PRODUCTLINE         False
# MSRP                False
# PRODUCTCODE         False
# PHONE               False
# CITY                False
# STATE                True
# POSTALCODE           True
# COUNTRY             False
# TERRITORY            True
# CONTACTLASTNAME     False
# CONTACTFIRSTNAME    False
# dtype: bool

# %% [markdown]
# # Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
df.fillna(0)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  \
# 0       10107               30      95.70                2  2871.00   Shipped
# 1       10121               34      81.35                5  2765.90   Shipped
# 2       10134               41      94.74                2  3884.34   Shipped
# 3       10145               45      83.26                6  3746.70   Shipped
# 4       10159               49     100.00               14  5205.27   Shipped
# ...       ...              ...        ...              ...      ...       ...
# 2818    10350               20     100.00               15  2244.40   Shipped
# 2819    10373               29     100.00                1  3978.51   Shipped
# 2820    10386               43     100.00                4  5417.57  Resolved
# 2821    10397               34      62.24                1  2116.16   Shipped
# 2822    10414               47      65.52                9  3079.44   On Hold
#
# ...

# %% [markdown]
# # Q9. How do you concatenate two Pandas DataFrames?

# %%
concat_df = pd.concat([df, new_df])
print(concat_df)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  \
# 0     10107.0               30      95.70                2  2871.00   Shipped
# 1     10121.0               34      81.35                5  2765.90   Shipped
# 2     10134.0               41      94.74                2  3884.34   Shipped
# 3     10145.0               45      83.26                6  3746.70   Shipped
# 4     10159.0               49     100.00               14  5205.27   Shipped
# ...       ...              ...        ...              ...      ...       ...
# 2818      NaN               20     100.00               15  2244.40   Shipped
# 2819      NaN               29     100.00                1  3978.51   Shipped
# 2820      NaN               43     100.00                4  5417.57  Resolved
# 2821      NaN               34      62.24                1  2116.16   Shipped
# 2822      NaN               47      65.52                9  3079.44   On Hold
#
# ...

# %% [markdown]
# # Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
df1 = df.drop(['CONTACTFIRSTNAME'], axis=1)
print(df1)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  \
# 0       10107               30      95.70                2  2871.00   Shipped
# 1       10121               34      81.35                5  2765.90   Shipped
# 2       10134               41      94.74                2  3884.34   Shipped
# 3       10145               45      83.26                6  3746.70   Shipped
# 4       10159               49     100.00               14  5205.27   Shipped
# ...       ...              ...        ...              ...      ...       ...
# 2818    10350               20     100.00               15  2244.40   Shipped
# 2819    10373               29     100.00                1  3978.51   Shipped
# 2820    10386               43     100.00                4  5417.57  Resolved
# 2821    10397               34      62.24                1  2116.16   Shipped
# 2822    10414               47      65.52                9  3079.44   On Hold
#
# ...

# %%
merged_df = pd.merge(df, df1, on= 'CONTACTLASTNAME')
print(merged_df)
# Out:
#         ORDERNO_x  QUANTITYORDERED_x  PRICEEACH_x  ORDERLINENUMBER_x  SALES_x  \
# 0           10107                 30        95.70                  2   2871.0
# 1           10107                 30        95.70                  2   2871.0
# 2           10107                 30        95.70                  2   2871.0
# 3           10107                 30        95.70                  2   2871.0
# 4           10107                 30        95.70                  2   2871.0
# ...           ...                ...          ...                ...      ...
# 210856      10144                 20        81.86                  1   1637.2
# 210857      10144                 20        81.86                  1   1637.2
# 210858      10144                 20        81.86                  1   1637.2
# 210859      10144                 20        81.86                  1   1637.2
# 210860      10144                 20        81.86                  1   1637.2
#
# ...

# %% [markdown]
# # Q11. How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %%
grouped_df = df.groupby('PRODUCTLINE').agg({'SALES': 'sum'})
print(grouped_df)
# Out:
#                        SALES
# PRODUCTLINE
# Classic Cars      3919615.66
# Motorcycles       1166388.34
# Planes             975003.57
# Ships              714437.13
# Trains             226243.47
# Trucks and Buses  1127789.84
# Vintage Cars      1903150.84

# %%
grouped_df1 = df.groupby('COUNTRY').agg({'PRODUCTLINE': 'count', 'SALES': 'sum'})
print(grouped_df1)
# Out:
#              PRODUCTLINE       SALES
# COUNTRY
# Australia            185   630623.10
# Austria               55   202062.53
# Belgium               33   108412.62
# Canada                70   224078.56
# Denmark               63   245637.15
# Finland               92   329581.91
# France               314  1110916.52
# Germany               62   220472.09
# Ireland               16    57756.43
# Italy                113   374674.31
# Japan                 52   188167.81
# Norway                85   307463.70
# Philippines           26    94015.73
# Singapore             79   288488.41
# Spain                342  1215686.92
# Sweden                57   210014.21
# Switzerland           31   117713.56
# UK                   144   478880.46
# USA                 1004  3627982.83

# %% [markdown]
# # Q12. How do you pivot a Pandas DataFrame?

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'City': ['New York', 'London', 'Tokyo', 'London', 'Tokyo'],
    'Year': [2020, 2020, 2020, 2021, 2021],
    'Sales': [100, 200, 150, 250, 180]
}
df = pd.DataFrame(data)

# Pivot the DataFrame
pivot_df = df.pivot(index='Year', columns='City', values='Sales')

# %%
print(pivot_df)
# Out:
# City  London  New York  Tokyo
# Year
# 2020   200.0     100.0  150.0
# 2021   250.0       NaN  180.0

# %% [markdown]
# # Q13. How do you change the data type of a column in a Pandas DataFrame?

# %%
df['PRICEEACH'] = df['PRICEEACH'].astype('int')

# %%
print(df['PRICEEACH'].dtype)
# Out:
# int32

# %% [markdown]
# # Q14. How do you sort a Pandas DataFrame by a specific column?

# %%
sorted_df = df.sort_values(by='COUNTRY', ascending =True)
print(sorted_df)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2075    10139               29        100                4  3276.13
# 778     10391               44         38                5  1694.00
# 776     10370               22         96                7  2130.92
# 774     10347               50        100                8  6834.50
# 752     10420               45        100                2  4977.00
# ...       ...              ...        ...              ...      ...
# 1360    10312               39         56                1  2217.15
# 1357    10281               44         59               14  2634.28
# 1354    10245               45         59                7  2694.15
# 1381    10264               20        100                2  2410.60
# 2822    10414               47         65                9  3079.44
#
#           STATUS  QTR_ID  MONTH_ID  YEAR_ID       PRODUCTLINE  MSRP  \
# 2075     Shipped       3         7     2003      Vintage Cars    97
# ...

# %% [markdown]
# # Q15. How do you create a copy of a Pandas DataFrame?

# %%
copied_df = df.copy()
print(copied_df)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  \
# 0       10107               30         95                2  2871.00   Shipped
# 1       10121               34         81                5  2765.90   Shipped
# 2       10134               41         94                2  3884.34   Shipped
# 3       10145               45         83                6  3746.70   Shipped
# 4       10159               49        100               14  5205.27   Shipped
# ...       ...              ...        ...              ...      ...       ...
# 2818    10350               20        100               15  2244.40   Shipped
# 2819    10373               29        100                1  3978.51   Shipped
# 2820    10386               43        100                4  5417.57  Resolved
# 2821    10397               34         62                1  2116.16   Shipped
# 2822    10414               47         65                9  3079.44   On Hold
#
# ...

# %% [markdown]
# # Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
filtered_df = df[(df['QTR_ID'] > 3) & (df['COUNTRY'] == 'USA' )]
print(filtered_df)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  \
# 4       10159               49        100               14  5205.27  Shipped
# 5       10168               36         96                1  3479.76  Shipped
# 8       10201               22         98                2  2168.54  Shipped
# 18      10318               46         94                1  4358.04  Shipped
# 19      10329               42        100                1  4396.14  Shipped
# ...       ...              ...        ...              ...      ...      ...
# 2786    10307               34         53                4  1823.42  Shipped
# 2788    10329               44         86                8  3789.72  Shipped
# 2790    10352               49         52                4  2579.36  Shipped
# 2804    10185               28         64                6  1804.04  Shipped
# 2817    10337               42         97                5  4080.72  Shipped
#
# ...

# %% [markdown]
# # Q17. How do you calculate the mean of a column in a Pandas DataFrame?

# %%
df['SALES'].mean()
# Out:
# 3553.88907190932

# %% [markdown]
# # Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
df['SALES'].std()
# Out:
# 1841.8651057401805

# %% [markdown]
# # Q19. How do you calculate the correlation between two columns in a Pandas DataFrame?

# %%
correlation = df['QUANTITYORDERED'].corr(df['PRICEEACH'])
print(correlation)
# Out:
# 0.005633519397582198

# %% [markdown]
# # Q20. How do you select specific columns in a DataFrame using their labels?

# %%
selected_df = df[['COUNTRY','PRODUCTLINE','STATUS','SALES']]
print(selected_df)
# Out:
#       COUNTRY  PRODUCTLINE    STATUS    SALES
# 0         USA  Motorcycles   Shipped  2871.00
# 1      France  Motorcycles   Shipped  2765.90
# 2      France  Motorcycles   Shipped  3884.34
# 3         USA  Motorcycles   Shipped  3746.70
# 4         USA  Motorcycles   Shipped  5205.27
# ...       ...          ...       ...      ...
# 2818    Spain        Ships   Shipped  2244.40
# 2819  Finland        Ships   Shipped  3978.51
# 2820    Spain        Ships  Resolved  5417.57
# 2821   France        Ships   Shipped  2116.16
# 2822      USA        Ships   On Hold  3079.44
#
# [2823 rows x 4 columns]

# %% [markdown]
# # Q21. How do you select specific rows in a DataFrame using their indexes?

# %%
selected_row = df.loc[[1,3,5]]
print(selected_row)
# Out:
#    ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  \
# 1    10121               34         81                5  2765.90  Shipped
# 3    10145               45         83                6  3746.70  Shipped
# 5    10168               36         96                1  3479.76  Shipped
#
#    QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP PRODUCTCODE       PHONE  \
# 1       2         5     2003  Motorcycles    95    S10_1678  26.47.1555
# 3       3         8     2003  Motorcycles    95    S10_1678  6265557265
# 5       4        10     2003  Motorcycles    95    S10_1678  6505556809
#
#          CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 1       Reims   NaN      51100  France      EMEA         Henriot
# 3    Pasadena    CA      90003     USA       NaN           Young
# 5  Burlingame    CA      94217     USA       NaN          Hirano
#
#   CONTACTFIRSTNAME
# 1             Paul
# 3            Julie
# 5             Juri

# %% [markdown]
# # Q22. How do you sort a DataFrame by a specific column?

# %%
df.sort_values(by = 'SALES', ascending = False).head(5)
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 598     10407               76        100                2  14082.8
# 744     10322               50        100                6  12536.5
# 53      10424               50        100                6  12001.0
# 1062    10412               60        100                9  11887.8
# 104     10403               66        100                9  11886.6
#
#           STATUS  QTR_ID  MONTH_ID  YEAR_ID   PRODUCTLINE  MSRP PRODUCTCODE  \
# 598      On Hold       2         4     2005  Vintage Cars   170    S18_1749
# 744      Shipped       4        11     2004  Vintage Cars   127    S18_2325
# 53    In Process       2         5     2005  Classic Cars   214    S10_1949
# 1062     Shipped       2         5     2005  Classic Cars   169    S18_3232
# 104      Shipped       2         4     2005   Motorcycles   193    S10_4698
#
#                PHONE       CITY STATE POSTALCODE COUNTRY TERRITORY  \
# ...

# %% [markdown]
# # Q23. How do you create a new column in a DataFrame based on the values of another column?

# %%
df['TOTALPRICE'] = df['PRICEEACH'] * 2

# %%
df.head(5)
# Out:
#    ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  \
# 0    10107               30         95                2  2871.00  Shipped
# 1    10121               34         81                5  2765.90  Shipped
# 2    10134               41         94                2  3884.34  Shipped
# 3    10145               45         83                6  3746.70  Shipped
# 4    10159               49        100               14  5205.27  Shipped
#
#    QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  PRODUCTCODE             PHONE  \
# 0       1         2     2003  Motorcycles  ...     S10_1678        2125557818
# 1       2         5     2003  Motorcycles  ...     S10_1678        26.47.1555
# 2       3         7     2003  Motorcycles  ...     S10_1678  +33 1 46 62 7555
# 3       3         8     2003  Motorcycles  ...     S10_1678        6265557265
# 4       4        10     2003  Motorcycles  ...     S10_1678        6505551386
#
# ...

# %% [markdown]
# # Q24. How do you remove duplicates from a DataFrame?

# %%
df.drop_duplicates()
# Out:
#       ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  \
# 0       10107               30         95                2  2871.00   Shipped
# 1       10121               34         81                5  2765.90   Shipped
# 2       10134               41         94                2  3884.34   Shipped
# 3       10145               45         83                6  3746.70   Shipped
# 4       10159               49        100               14  5205.27   Shipped
# ...       ...              ...        ...              ...      ...       ...
# 2818    10350               20        100               15  2244.40   Shipped
# 2819    10373               29        100                1  3978.51   Shipped
# 2820    10386               43        100                4  5417.57  Resolved
# 2821    10397               34         62                1  2116.16   Shipped
# 2822    10414               47         65                9  3079.44   On Hold
#
# ...

# %% [markdown]
# # Q25. What is the difference between .loc and .iloc in Pandas?

# %% [markdown]
# .loc and .iloc are used in slicing data.
# .loc method includes the last element of the range passed in it, unlike iloc().
# .loc() can accept the boolean data unlike iloc().

# %%
df.loc[2:5]
# Out:
#    ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  \
# 2    10134               41         94                2  3884.34  Shipped
# 3    10145               45         83                6  3746.70  Shipped
# 4    10159               49        100               14  5205.27  Shipped
# 5    10168               36         96                1  3479.76  Shipped
#
#    QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  PRODUCTCODE             PHONE  \
# 2       3         7     2003  Motorcycles  ...     S10_1678  +33 1 46 62 7555
# 3       3         8     2003  Motorcycles  ...     S10_1678        6265557265
# 4       4        10     2003  Motorcycles  ...     S10_1678        6505551386
# 5       4        10     2003  Motorcycles  ...     S10_1678        6505556809
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 2          Paris   NaN      75508  France      EMEA        Da Cunha
# ...

# %%
df.iloc[2:5]
# Out:
#    ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  \
# 2    10134               41         94                2  3884.34  Shipped
# 3    10145               45         83                6  3746.70  Shipped
# 4    10159               49        100               14  5205.27  Shipped
#
#    QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  PRODUCTCODE             PHONE  \
# 2       3         7     2003  Motorcycles  ...     S10_1678  +33 1 46 62 7555
# 3       3         8     2003  Motorcycles  ...     S10_1678        6265557265
# 4       4        10     2003  Motorcycles  ...     S10_1678        6505551386
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 2          Paris   NaN      75508  France      EMEA        Da Cunha
# 3       Pasadena    CA      90003     USA       NaN           Young
# 4  San Francisco    CA        NaN     USA       NaN           Brown
#
#   CONTACTFIRSTNAME TOTALPRICE
# 2           Daniel        188
# ...

# %%
# selecting rows from 1 to 4 and columns from 2 to 4
# if we have to print row and column
df.iloc[1: 5, 2: 5]
# Out:
#    PRICEEACH  ORDERLINENUMBER    SALES
# 1         81                5  2765.90
# 2         94                2  3884.34
# 3         83                6  3746.70
# 4        100               14  5205.27

# %%
df.loc[1: 5]
# Out:
#    ORDERNO  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  \
# 1    10121               34         81                5  2765.90  Shipped
# 2    10134               41         94                2  3884.34  Shipped
# 3    10145               45         83                6  3746.70  Shipped
# 4    10159               49        100               14  5205.27  Shipped
# 5    10168               36         96                1  3479.76  Shipped
#
#    QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  PRODUCTCODE             PHONE  \
# 1       2         5     2003  Motorcycles  ...     S10_1678        26.47.1555
# 2       3         7     2003  Motorcycles  ...     S10_1678  +33 1 46 62 7555
# 3       3         8     2003  Motorcycles  ...     S10_1678        6265557265
# 4       4        10     2003  Motorcycles  ...     S10_1678        6505551386
# 5       4        10     2003  Motorcycles  ...     S10_1678        6505556809
#
# ...
